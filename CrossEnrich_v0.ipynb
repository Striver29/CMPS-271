# %% [markdown]
# <a href="https://colab.research.google.com/github/Striver29/CMPS-271/blob/main/CrossEnrich_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gprofiler-official --quiet
print("done")
# Out:
# done
